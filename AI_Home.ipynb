# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('house-prices.csv')

# %%
df.describe()
# Out:
#              Home          Price         SqFt    Bedrooms   Bathrooms  \
# count  128.000000     128.000000   128.000000  128.000000  128.000000
# mean    64.500000  130427.343750  2000.937500    3.023438    2.445312
# std     37.094474   26868.770371   211.572431    0.725951    0.514492
# min      1.000000   69100.000000  1450.000000    2.000000    2.000000
# 25%     32.750000  111325.000000  1880.000000    3.000000    2.000000
# 50%     64.500000  125950.000000  2000.000000    3.000000    2.000000
# 75%     96.250000  148250.000000  2140.000000    3.000000    3.000000
# max    128.000000  211200.000000  2590.000000    5.000000    4.000000
#
#            Offers
# count  128.000000
# mean     2.578125
# std      1.069324
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      3.000000
# max      6.000000

# %%
x = df.drop("Price", axis=1)
x = x.drop("Brick", axis=1)
x = x.drop("Neighborhood", axis=1)
y=df.Price

# %%
x
# Out:
#      Home  SqFt  Bedrooms  Bathrooms  Offers
# 0       1  1790         2          2       2
# 1       2  2030         4          2       3
# 2       3  1740         3          2       1
# 3       4  1980         3          2       3
# 4       5  2130         3          3       3
# ..    ...   ...       ...        ...     ...
# 123   124  1900         3          3       3
# 124   125  2160         4          3       3
# 125   126  2070         2          2       2
# 126   127  2020         3          3       1
# 127   128  2250         3          3       4
#
# [128 rows x 5 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.9)

# %%
X_test
# Out:
#      Home  SqFt  Bedrooms  Bathrooms  Offers
# 88     89  1930         3          3       2
# 29     30  2040         4          3       1
# 113   114  2000         3          2       3
# 82     83  2050         2          2       1
# 72     73  1650         3          2       3
# ..    ...   ...       ...        ...     ...
# 6       7  1830         3          3       3
# 56     57  2190         3          2       3
# 111   112  1740         2          2       2
# 118   119  1950         3          2       3
# 122   123  2060         2          2       1
#
# [116 rows x 5 columns]

# %%
reg_linear=linear_model.LinearRegression()

# %%
reg_linear.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_test_pred=reg_linear.predict(X_test)

# %%
Y_test_pred
# Out:
# array([142383.46559984, 169204.09651688, 102693.51292593, 145675.91557911,
#         95057.37598506, 101505.32899295, 149799.49254798, 150923.75501548,
#        134341.53861426, 149884.1734901 , 105933.03971552, 142246.87618498,
#        136885.0177123 , 121949.51448722, 182569.75182835, 114405.11920598,
#        101426.72290482, 131264.70281803, 123201.61210247, 131737.06259935,
#        147501.31094125, 128227.74692624, 148543.13647531, 131123.90166329,
#        101802.34981694, 104048.14312661, 135849.68686113, 131067.1164863 ,
#        159452.69525392, 110623.37303085, 137850.83206831,  91442.71768322,
#        119450.38774455, 142018.69246505, 150293.69545037, 128678.20129339,
#        121075.92161516, 105145.68461995, 139838.39188194, 119957.68843295,
#        142985.64382654, 138551.99496522, 106915.34066403, 147955.6272957 ,
#         96244.41512934, 152568.41595739, 135405.18505945, 125846.05916836,
# ...

# %%
Y_test
# Out:
# 88     127700
# 29     188000
# 113    115700
# 82     164800
# 72     107300
#         ...
# 6      151600
# 56     140900
# 111    114900
# 118    150200
# 122    144800
# Name: Price, Length: 116, dtype: int64

# %%
feature1 = float(input("please take your Home: "))
feature2 = float(input("please take your SqFt: "))
feature3 = float(input("please take your Bedrooms: "))
feature4 = float(input("please take your Bathrooms: "))
feature5 = float(input("please take your Offers: "))

user_input = np.array([[feature1, feature2, feature3, feature4, feature5]])

# %%
v = reg_linear.predict(user_input)
print(v)
# Out:
# [142383.46559984]
# c:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
